# %%
import pandas as pd

# Read data from wines csv file
wines = pd.read_csv("winemag-data-130k-v2.csv",index_col = 0)
wines.head(3)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points  price           province           region_1           region_2  \
# 0      87    NaN  Sicily & Sardinia               Etna                NaN
# 1      87   15.0              Douro                NaN                NaN
# 2      87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# ...

# %%
wines.loc[:5,["taster_twitter_handle","taster_name","winery"]]
# Out:
#   taster_twitter_handle         taster_name               winery
# 0          @kerinokeefe       Kerin O’Keefe              Nicosia
# 1            @vossroger          Roger Voss  Quinta dos Avidagos
# 2           @paulgwine         Paul Gregutt            Rainstorm
# 3                   NaN  Alexander Peartree           St. Julian
# 4           @paulgwine         Paul Gregutt         Sweet Cheeks
# 5           @wineschach   Michael Schachner               Tandem

# %%
# Make copy of dataset to test on 
wines2 = wines.copy()
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points  price           province           region_1           region_2  \
# 0      87    NaN  Sicily & Sardinia               Etna                NaN
# 1      87   15.0              Douro                NaN                NaN
# 2      87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# ...

# %%
wines2.loc[(wines2.points >= 85) & (wines2.country == "Italy") & (wines2.price.notnull()) & wines2.country]
# wines2.loc[(wines2.points <= 85) | (wines2.country == "Italy")]
wines2.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wines2.loc[wines2.country.isin(["Portugal"]) & wines2.price.notnull()].shape
# Out:
# (22651, 13)

# %%
## Assigning data

wines2["critic"] = "everyone"
wines2["index_backwards"] = range(len(wines2),0,-1)
wines2.head(3)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points  price           province           region_1           region_2  \
# 0      87    NaN  Sicily & Sardinia               Etna                NaN
# 1      87   15.0              Douro                NaN                NaN
# 2      87   14.0             Oregon  Willamette Valley  Willamette Valley
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# ...

# %%
wines2.description[0]
wines2.loc[:,"description"]
df = wines2.loc[[0,1,10,100],["country","province","region_1","region_2"]]
df2 = wines2.loc[:,["price"]]
df2
df3 = wines2.loc[wines2.price.isnull()]
df3
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 13         Italy  This is dominated by oak and oak-driven aromas...
# 30        France  Red cherry fruit comes laced with light tannin...
# 31         Italy  Merlot and Nero d'Avola form the base for this...
# 32         Italy  Part of the extended Calanìca series, this Gri...
# ...          ...                                                ...
# 129844     Italy  Doga delle Clavule is a neutral, mineral-drive...
# 129860  Portugal  This rich wine has a firm structure as well as...
# 129863  Portugal  This mature wine that has 50% Touriga Nacional...
# 129893     Italy  Aromas of passion fruit, hay and a vegetal not...
# 129964    France  Initially quite muted, this wine slowly develo...
#
#                          designation  points  price           province  \
# 0                       Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
unique = wines2.country.unique()
print(unique)
describe = wines2.country.describe()
print(describe)
value_counts = wines2.country.value_counts()
print(value_counts)
# Out:
# ['Italy' 'Portugal' 'US' 'Spain' 'France' 'Germany' 'Argentina' 'Chile'
#  'Australia' 'Austria' 'South Africa' 'New Zealand' 'Israel' 'Hungary'
#  'Greece' 'Romania' 'Mexico' 'Canada' nan 'Turkey' 'Czech Republic'
#  'Slovenia' 'Luxembourg' 'Croatia' 'Georgia' 'Uruguay' 'England' 'Lebanon'
#  'Serbia' 'Brazil' 'Moldova' 'Morocco' 'Peru' 'India' 'Bulgaria' 'Cyprus'
#  'Armenia' 'Switzerland' 'Bosnia and Herzegovina' 'Ukraine' 'Slovakia'
#  'Macedonia' 'China' 'Egypt']
# count     129908
# unique        43
# top           US
# freq       54504
# Name: country, dtype: object
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# ...

# %%
# map for series data
# The function you pass to map() should expect a single value from the Series (a point value, in the above example), and return a transformed version of that value. map() returns a new Series where all the values have been transformed by your function.

points_mean = wines2.points.map(lambda p: p - wines2.points.mean())
print(points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
# 2        -1.447138
# 3        -1.447138
# 4        -1.447138
#             ...
# 129966    1.552862
# 129967    1.552862
# 129968    1.552862
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
# apply() to transform a whole DatFrame by calling a custom method on each row

def remean_points(row):
    row["mean_diff"] = row.points - wines2.points.mean()
    return row

# %timeit wines2.apply(remean_points,axis = 'columns') # didnt apply it to the DF
#print(wines2.head(1))

# Notice: If we had called reviews.apply() with axis='index',
# then instead of passing a function to transform each row, 
# we would need to give a function to transform each column.

#wines2.apply(remean_points,axis = 'index')
#print(wines2.head(3))
# NOTE: Note that map() and apply() return new, transformed Series and DataFrames, respectively. 
# They don't modify the original data they're called on. If we look at the first row of reviews, we can see that it still has its original points value.
# Out:
# 4min 46s ± 23.8 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
#
#   taster_twitter_handle                              title      variety  \
# 0          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
#
#     winery    critic  index_backwards
# 0  Nicosia  everyone           129971

# %%
import numpy as np
#a = np.arange(1000)
#%timeit a ** 2
# %timeit centered_price = wines2.price.mean() - wines2.price
#print(centered_price)
# Out:
# 1.87 ms ± 57.2 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# I'm an economical wine buyer. Which wine is the "best bargain"? Create a variable bargain_wine with the title of the wine with the highest points-to-price ratio in the dataset.

# %%
bargain_idx = (wines2.points / wines2.price).idxmax()
bargain_wine = wines2.loc[bargain_idx,"title"]
print(bargain_wine)
# Out:
# Bandit NV Merlot (California)

# %%
# Optimize by checking times for functions

from timeit import default_timer as timer
from functools import wraps

def timing(f):
    @wraps(f)
    def wrap(*args, **kw):
        start = timer()
        result = f(*args, **kw)
        end = timer()
        print('func:%r args:[%r, %r] took: %2.4f sec' % \
          (f.__name__, args, kw, end - start))
        return result
    return wrap



@timing
def compare_minus(a):
    for _ in range(a):
        centered_price = wines2.price.mean() - wines2.price
    return centered_price

@timing
def compare_map(a):
    mean = wines2.price.mean()
    for _ in range(a):
        map_mean = wines2.price.map(lambda p: p - mean)
    return map_mean

print(compare_minus(1))
print(compare_map(1))
# Out:
# func:'compare_minus' args:[(1,), {}] took: 0.0023 sec
# 0               NaN
# 1         20.363389
# 2         21.363389
# 3         22.363389
# 4        -29.636611
#             ...
# 129966     7.363389
# 129967   -39.636611
# 129968     5.363389
# 129969     3.363389
# 129970    14.363389
# Name: price, Length: 129971, dtype: float64
# func:'compare_map' args:[(1,), {}] took: 0.0871 sec
# 0               NaN
# 1        -20.363389
# 2        -21.363389
# 3        -22.363389
# 4         29.636611
#             ...
# 129966    -7.363389
# 129967    39.636611
# 129968    -5.363389
# 129969    -3.363389
# 129970   -14.363389
# Name: price, Length: 129971, dtype: float64

# %% [markdown]
# ### There are only so many words you can use when describing a bottle of wine. Is a wine more likely to be "tropical" or "fruity"? Create a Series descriptor_counts counting how many times each of these two words appears in the description column in the dataset

# %%
fruity_counts = wines2.description.map(lambda desc: ("fruity" in desc)).sum()
descriptor_counts = pd.Series([fruity_counts,tropical_counts],index = ["fruity","tropical"])
descriptor_counts
# Out:
# fruity      9090
# tropical    3607
# dtype: int64

# %% [markdown]
# ### We'd like to host these wine reviews on our website, but a rating system ranging from 80 to 100 points is too hard to understand - we'd like to translate them into simple star ratings. A score of 95 or higher counts as 3 stars, a score of at least 85 but less than 95 is 2 stars. Any other score is 1 star.
#
# ### Also, the Canadian Vintners Association bought a lot of ads on the site, so any wines from Canada should automatically get 3 stars, regardless of points.
#
# ### Create a series star_ratings with the number of stars corresponding to each review in the dataset.

# %%
def stars(row):
    
    if row.points >= 95:
        return 3
    elif row.country == "Canada":
        return 3
    elif row.points >= 85:
        return 2
    else:
        return 1
    
star_ratings = wines2.apply(stars, axis = "columns")
star_ratings
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 129966    2
# 129967    2
# 129968    2
# 129969    2
# 129970    2
# Length: 129971, dtype: int64

# %%
### Groupby

wines2.groupby("points").points.count()

# to get the cheapest wine in each point value category
wines2.groupby("points").price.min()

# select the name of the first wine reviewed from each winery in the dataset

wines2.groupby("winery").apply(lambda df: df.title.iloc[0])

# group by more than one column. For an example, here's how we would pick out the best wine by country and province:
best_wine_cp = wines2.groupby(["country","province"]).apply(lambda df: df.loc[df.points.idxmax()]).winery.head(5)
print(best_wine_cp)
country_price_agg = wines2.groupby("country").price.agg([len,min,max])


country_wine = wines2.groupby(["country","province"]).description.agg([len])
print(type(country_wine.index)) # Multi-index


country_wine = country_wine.reset_index() # reset index for multi-index

country_wine.sort_values(by = "len", ascending = False)
print(country_wine)
print(type(country_wine.index))
# Out:
# country    province
# Argentina  Mendoza Province    Bodega Catena Zapata
#            Other                             Colomé
# Armenia    Armenia                         Van Ardi
# Australia  Australia Other          Marquis Philips
#            New South Wales               De Bortoli
# Name: winery, dtype: object
# <class 'pandas.core.indexes.multi.MultiIndex'>
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# 2      Armenia           Armenia     2
# 3    Australia   Australia Other   245
# 4    Australia   New South Wales    85
# ..         ...               ...   ...
# 420    Uruguay           Juanico    12
# 421    Uruguay        Montevideo    11
# 422    Uruguay          Progreso    11
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]
# <class 'pandas.core.indexes.range.RangeIndex'>

# %% [markdown]
# Who are the most common wine reviewers in the dataset? Create a Series whose index is the taster_twitter_handle category from the dataset, and whose values count how many reviews each person wrote.

# %%
reviews_written1 = wines2.groupby('taster_twitter_handle').size()
print(reviews_written1)

# OR

reviews_written2 = wines2.groupby("taster_twitter_handle").taster_twitter_handle.count()
print(reviews_written2)
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery', 'critic', 'index_backwards'],
#       dtype='object')
# taster_twitter_handle
# @AnneInVino          3685
# @JoeCz               5147
# @bkfiona               27
# @gordone_cellars     4177
# @kerinokeefe        10776
# @laurbuzz            1835
# @mattkettmann        6332
# @paulgwine           9532
# @suskostrzewa        1085
# @vboone              9537
# @vossroger          25514
# @wawinereport        4966
# @wineschach         15134
# @winewchristina         6
# @worldwineguys       1005
# dtype: int64
# taster_twitter_handle
# @AnneInVino          3685
# @JoeCz               5147
# @bkfiona               27
# @gordone_cellars     4177
# @kerinokeefe        10776
# @laurbuzz            1835
# @mattkettmann        6332
# @paulgwine           9532
# @suskostrzewa        1085
# ...

# %% [markdown]
# What is the best wine I can buy for a given amount of money? Create a Series whose index is wine prices and whose values is the maximum number of points a wine costing that much was given in a review. Sort the values by price, ascending (so that 4.0 dollars is at the top and 3300.0 dollars is at the bottom).

# %%
best_rating_per_price = wines2.groupby("price").points.max().sort_index() 

# notice we want to sort by price, but its the index so using sort_index() method, for sort_values(), i think it would be by the values by default 
print(best_rating_per_price)


# OR


best_rating_per_price = wines2.groupby("price")["points"].max().sort_index()
print(best_rating_per_price)
# Out:
# price
# 4.0       86
# 5.0       87
# 6.0       88
# 7.0       91
# 8.0       91
#           ..
# 1900.0    98
# 2000.0    97
# 2013.0    91
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64
# price
# 4.0       86
# 5.0       87
# 6.0       88
# 7.0       91
# 8.0       91
#           ..
# 1900.0    98
# 2000.0    97
# 2013.0    91
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %% [markdown]
# What are the minimum and maximum prices for each `variety` of wine? Create a `DataFrame` whose index is the `variety` category from the dataset and whose values are the `min` and `max` values thereof

# %%
price_extremes = wines2.groupby("variety").price.agg(["min","max"])
print(price_extremes)
# Out:
#               min    max
# variety
# Abouriou     15.0   75.0
# Agiorgitiko  10.0   66.0
# Aglianico     6.0  180.0
# Aidani       27.0   27.0
# Airen         8.0   10.0
# ...           ...    ...
# Zinfandel     5.0  100.0
# Zlahtina     13.0   16.0
# Zweigelt      9.0   70.0
# Çalkarası    19.0   19.0
# Žilavka      15.0   15.0
#
# [707 rows x 2 columns]

# %% [markdown]
# What are the most expensive wine varieties? Create a variable `sorted_varieties` containing a copy of the dataframe from the previous question where varieties are sorted in descending order based on minimum price, then on maximum price (to break ties).

# %%
sorted_varieties = price_extremes.sort_values(by = ["min","max"], ascending = False)
print(sorted_varieties)
# Out:
#                                   min    max
# variety
# Ramisco                         495.0  495.0
# Terrantez                       236.0  236.0
# Francisa                        160.0  160.0
# Rosenmuskateller                150.0  150.0
# Tinta Negra Mole                112.0  112.0
# ...                               ...    ...
# Roscetto                          NaN    NaN
# Sauvignon Blanc-Sauvignon Gris    NaN    NaN
# Tempranillo-Malbec                NaN    NaN
# Vital                             NaN    NaN
# Zelen                             NaN    NaN
#
# [707 rows x 2 columns]

# %% [markdown]
# Create a `Series` whose index is reviewers and whose values is the average review score given out by that reviewer. Hint: you will need the `taster_name` and `points` columns.

# %%
reviewer_mean_ratings = wines2.groupby("taster_name").points.mean()
print(reviewer_mean_ratings)
# Also see describe to see the summary of the range of values
reviewer_mean_ratings.describe()
# Out:
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
# Anne Krebiehl MW      90.562551
# Carrie Dykes          86.395683
# Christina Pickard     87.833333
# Fiona Adams           86.888889
# Jeff Jenssen          88.319756
# Jim Gordon            88.626287
# Joe Czerwinski        88.536235
# Kerin O’Keefe         88.867947
# Lauren Buzzeo         87.739510
# Matt Kettmann         90.008686
# Michael Schachner     86.907493
# Mike DeSimone         89.101167
# Paul Gregutt          89.082564
# Roger Voss            88.708003
# Sean P. Sullivan      88.755739
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# Name: points, dtype: float64
# count    19.000000
# mean     88.233026
# std       1.243610
# min      85.855422
# 25%      87.323501
# 50%      88.536235
# 75%      88.975256
# max      90.562551
# Name: points, dtype: float64

# %% [markdown]
# What combination of countries and varieties are most common? Create a Series whose index is a MultiIndexof {country, variety} pairs. For example, a pinot noir produced in the US should map to {"US", "Pinot Noir"}. Sort the values in the Series in descending order based on wine count.

# %%
country_variety_counts = wines2.groupby(["country","variety"]).variety.count().sort_values(ascending = False)
country_variety_counts
# Out:
# country    variety
# US         Pinot Noir                  9885
#            Cabernet Sauvignon          7315
#            Chardonnay                  6801
# France     Bordeaux-style Red Blend    4725
# Italy      Red Blend                   3624
#                                        ...
# Uruguay    Tempranillo-Tannat             1
# Italy      Pignolo                        1
#            Muscat                         1
#            Moscato di Noto                1
# Argentina  Barbera                        1
# Name: variety, Length: 1612, dtype: int64

# %% [markdown]
# ### Data types for series and data frames

# %%
print(wines2.price.dtypes) # dtype for a series
print("\n--------------\n")
print(wines2.dtypes)  # dtype for a dataframe
# Out:
# float64
#
# --------------
#
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# critic                    object
# index_backwards            int64
# dtype: object

# %%
### Convert int64 to float64 using astype()

wines2.points.astype('float64')

# dtype for DF or Series index

wines2.index.dtype
# Out:
# dtype('int64')

# %%
### Missing Data

# %%
# print(wines2.isnull())
# print(wines2.notnull())
# print(wines2.points.isnull())

print("\n--------------\n")
print(wines2[pd.isnull(wines2.country)])
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       NaN  Violet-red in color, this semisweet wine has a...
# 9509       NaN  This mouthwatering blend starts with a nose of...
# 9750       NaN  This orange-style wine has a cloudy yellow-gol...
# ...        ...                                                ...
# 124176     NaN  This Swiss red blend is composed of four varie...
# 129407     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129408     NaN  El Capricho is one of Uruguay's more consisten...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#                            designation  points  price province region_1  \
# 913                     Asureti Valley      87   30.0      NaN      NaN
# ...

# %%
### Replace missing values

# %%
wines2.region_2.fillna("Unknown")
# Out:
# 0                   Unknown
# 1                   Unknown
# 2         Willamette Valley
# 3                   Unknown
# 4         Willamette Valley
#                 ...
# 129966              Unknown
# 129967         Oregon Other
# 129968              Unknown
# 129969              Unknown
# 129970              Unknown
# Name: region_2, Length: 129971, dtype: object

# %%
### Replacing values with other values

wines2.taster_twitter_handle.replace("@kerinokeefe","@kerino")
# Out:
# 0             @kerino
# 1          @vossroger
# 2         @paulgwine
# 3                 NaN
# 4         @paulgwine
#              ...
# 129966            NaN
# 129967    @paulgwine
# 129968     @vossroger
# 129969     @vossroger
# 129970     @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %% [markdown]
# What are the most common wine-producing regions? Create a Series counting the number of times each value occurs in the region_1 field. This field is often missing data, so replace missing values with Unknown. Sort in descending order. Your output should look something like this:

# %%
reviews_per_region = wines2.region_1.fillna("Unknown").value_counts().sort_values(ascending = False)

reviews_per_region
# Out:
# Unknown                              21247
# Napa Valley                           4480
# Columbia Valley (WA)                  4124
# Russian River Valley                  3091
# California                            2629
#                                      ...
# Grave del Friuli                         1
# Napa County-Lake County                  1
# Cabernet de Saumur                       1
# Valpolicella Valpantena Superiore        1
# Henty                                    1
# Name: region_1, Length: 1230, dtype: int64

# %% [markdown]
# ### Renaming

# %%
# Use rename() to change index names and/or column names. CHange the points column in the dataset to score:

wines2.rename(columns = {"points":"score"})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  score  price  \
# 0                                 Vulkà Bianco     87    NaN
# ...

# %%
# Rename index using a disctionary

wines2.rename(index = {0: "firstEntry", 1 : "secondEntry"})

# Or use set_index()

#Both row index and column index can have their own name attribute. THe complimentary rename_axis() method may be used to change these names.

wines2.rename_axis("wines",axis = "rows").rename_axis("fields",axis = "columns")
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# fields                             designation  points  price  \
# wines
# 0                                 Vulkà Bianco      87    NaN
# ...

# %% [markdown]
# region_1 and region_2 are pretty uninformative names for locale columns in the dataset. Create a copy of reviews with these columns renamed to region and locale, respectively.

# %%
renamed = wines2.rename(columns = {"region_1":"region","region_2":"locale"})

# set the index name in the dataset to wines
reindexed = wines2.rename_axis("wines", axis = "rows")
reindexed
# Out:
#          country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# wines
# 0                                 Vulkà Bianco      87    NaN
# ...

# %% [markdown]
# ### Combining
#     Combining different DataFrames and/or Series in non-trivial ways

# %%
### Example
# canadian_youtube = pd.read_csv("../input/youtube-new/CAvideos.csv")
# british_youtube = pd.read_csv("../input/youtube-new/GBvideos.csv")

# pd.concat([canadian_youtube, british_youtube])

# left = canadian_youtube.set_index(['title', 'trending_date'])
# right = british_youtube.set_index(['title', 'trending_date'])

# left.join(right, lsuffix='_CAN', rsuffix='_UK')

# The lsuffix and rsuffix parameters are necessary here because the data has the same column names in both British and Canadian datasets. If this wasn't true (because, say, we'd renamed them beforehand) we wouldn't need them.
